# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
from sklearn.preprocessing import StandardScaler
pd.set_option('display.max_columns', None)
data = load_breast_cancer()

df = pd.DataFrame(data.data, columns=data.feature_names)
df['IsCancer'] = data.target
df.head(5)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  radius error  texture error  perimeter error  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

from sklearn.pipeline import make_pipeline
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=12,test_size=.3)
from sklearn.svm import SVC, SVR
pipe = make_pipeline(StandardScaler(),LogisticRegression(random_state=12, max_iter=1000))
pipe.fit(x_train, y_train)
a = pipe.score(x_test, y_test)

pipe2=make_pipeline(StandardScaler(),KNeighborsClassifier(n_jobs=-1,n_neighbors=3))
b=pipe2.fit(x_train,y_train).score(x_test,y_test)
pipe3=make_pipeline(StandardScaler(),SVC())
c=pipe3.fit(x_test,y_test).score(x_train,y_train)
print(a,b,c)
# Out:
# 0.9824561403508771 0.9532163742690059 0.9849246231155779

# %%
from sklearn.model_selection import RandomizedSearchCV

params = {
    'svc__C': [0.001,0.01,0.1,1,10,100,1000],
    'svc__kernel':['linear','poly','rbf','sigmoid'],
    'svc__gamma':['scale','auto',0.001,0.01,0.1,1]
}
random_search=RandomizedSearchCV(estimator=pipe3,param_distributions=params,cv=10,random_state=12,verbose=1,n_jobs=-1)
random_search.fit(x_train,y_train)
best=random_search.best_estimator_
print(random_search.best_score_)
print(random_search.best_params_)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# 0.9722435897435897
# {'svc__kernel': 'linear', 'svc__gamma': 1, 'svc__C': 10}

# %%
from sklearn.model_selection import GridSearchCV
params = {
    'svc__C':[0.001,0.01, 0.1,1,10,100,1000],
    'svc__kernel':['linear','poly','rbf','sigmoid'],
    'svc__gamma':['scale','auto',0.001,0.01,0.1,1]
}
random_search=GridSearchCV(estimator=pipe3,param_grid=params,cv=10,verbose=1,n_jobs=-1)
random_search.fit(x_train,y_train)
best=random_search.best_estimator_
print(random_search.best_score_)
print(random_search.best_params_)
# Out:
# Fitting 10 folds for each of 168 candidates, totalling 1680 fits
# 0.985
# {'svc__C': 100, 'svc__gamma': 'scale', 'svc__kernel': 'rbf'}
