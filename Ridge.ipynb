# %%
import pandas as pd
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
x,y=make_regression(n_samples=100,n_features=4,noise=1,random_state=12,effective_rank=2)
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=12)

pipe=make_pipeline(StandardScaler(),Ridge())
pipe.fit(x_train,y_train)
ypred=pipe.predict(x_test)
mae=mean_absolute_error(y_test,ypred)
mse=mean_squared_error(y_test,ypred)
r=r2_score(y_test,ypred)
print(mae,mse,r)
# Out:
# 0.9049745284573683 1.1870635073073188 0.9861233245384485

# %%
from sklearn.model_selection import GridSearchCV 
params={
    'ridge__alpha':[.0001,.001,.01,.1,1,10,100,1000,10000]
}
                        #accuracy is for classification models,r2 for reg
grid_search=GridSearchCV(estimator=pipe,param_grid=params,verbose=0,scoring='r2',n_jobs=-1,cv=15)
grid_search.fit(x_train,y_train)

print(grid_search.best_estimator_);print(grid_search.best_params_);print(grid_search.best_score_)
pipe
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('ridge', Ridge(alpha=0.01))])
# {'ridge__alpha': 0.01}
# 0.9686363430316718
# Pipeline(steps=[('standardscaler', StandardScaler()), ('ridge', Ridge())])

# %%
best_model=grid_search.best_estimator_
print(mean_absolute_error(y_test,best_model.predict(x_test)))
print(mean_squared_error(y_test,best_model.predict(x_test)))
print(r2_score(y_test,best_model.predict(x_test)))
print(best_model[1].coef_)
print(best_model[1].intercept_)
# Out:
# 0.8447161483799583
# 1.094818665817408
# 0.9872016592024981
# [4.59524161 5.9881182  7.36022472 6.42472424]
# -1.6944688595227495
